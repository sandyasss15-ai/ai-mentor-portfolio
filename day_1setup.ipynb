# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid describes a progression of AI capabilities, from foundational data processing to strategic goal-setting:
#
# *   **1. Data & Algorithms:** The base layer involving data collection, cleaning, storage, and the foundational algorithms (e.g., machine learning models) used to process it.
# *   **2. Intelligence & Learning:** The ability of AI to learn from data, recognize patterns, make predictions, and generate insights based on its training.
# *   **3. Autonomy & Adaptation:** The capacity for AI to operate independently, make decisions, and adapt its behavior in dynamic environments without constant human intervention.
# *   **4. Agency & Purpose:** The pinnacle layer where AI can understand context, set its own goals, and act with strategic intent to fulfill a broader objective.
