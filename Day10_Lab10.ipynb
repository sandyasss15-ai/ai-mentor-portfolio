# %% [markdown]
# <a href="https://colab.research.google.com/github/sandyasss15-ai/ai-mentor-portfolio/blob/main/Day10_Lab10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q "numpy<2.0"
# !pip install -q --upgrade crewai litellm google-generativeai google-genai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 80.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.3 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# tifffile 2026.4.11 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 3.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.5/89.5 kB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 1.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.4/68.4 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 976.4/976.4 kB 41.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.5/111.5 kB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 81.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 822.5/822.5 kB 41.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.9/19.9 MB 74.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.1/278.1 kB 17.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.1/246.1 kB 16.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.2/178.2 kB 11.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.9/46.9 MB 14.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 16.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.7/55.7 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.5/118.5 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.2/196.2 kB 12.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 80.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.6/803.6 kB 39.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 18.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 360.7/360.7 kB 21.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 108.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 334.8/334.8 kB 19.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 79.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 86.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.1/731.1 kB 28.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.5/310.5 kB 17.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.3/122.3 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.9/24.9 MB 23.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.47.0, but you have google-auth 2.53.0 which is incompatible.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-api>=1.35.0, but you have opentelemetry-api 1.34.1 which is incompatible.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-sdk<1.39.0,>=1.35.0, but you have opentelemetry-sdk 1.34.1 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# google-adk 1.29.0 requires google-genai<2.0.0,>=1.64.0, but you have google-genai 2.7.0 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-api<1.39.0,>=1.36.0, but you have opentelemetry-api 1.34.1 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-exporter-otlp-proto-http>=1.36.0, but you have opentelemetry-exporter-otlp-proto-http 1.34.1 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-sdk<1.39.0,>=1.36.0, but you have opentelemetry-sdk 1.34.1 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# wandb 0.27.0 requires click>=8.2.0, but you have click 8.1.8 which is incompatible.
# bigframes 2.40.0 requires rich<14,>=12.4.4, but you have rich 14.3.4 which is incompatible.

# %%
import os, getpass

os.environ["GEMINI_API_KEY"] = getpass.getpass("Enter Gemini API Key: ")

print("API key set")
# Out:
# Enter Gemini API Key: ··········
# API key set

# %%
from crewai import Agent, Task, Crew, Process

print("CrewAI imported successfully")
# Out:
# 05:18:11 - LiteLLM:WARNING: common_utils.py:979 - litellm: could not pre-load bedrock-runtime response stream shape — Bedrock event-stream decoding will be unavailable. Error: No module named 'botocore'
# WARNING:LiteLLM:litellm: could not pre-load bedrock-runtime response stream shape — Bedrock event-stream decoding will be unavailable. Error: No module named 'botocore'
# 05:18:11 - LiteLLM:WARNING: common_utils.py:24 - litellm: could not pre-load sagemaker-runtime response stream shape — SageMaker event-stream decoding will be unavailable. Error: No module named 'botocore'
# WARNING:LiteLLM:litellm: could not pre-load sagemaker-runtime response stream shape — SageMaker event-stream decoding will be unavailable. Error: No module named 'botocore'
# CrewAI imported successfully

# %%
llm = "gemini/gemini-2.5-flash"

print(llm)
# Out:
# gemini/gemini-2.5-flash

# %%
researcher = Agent(
    role="Placement Researcher",
    goal="Compile concise, factual placement-prep notes for B.Tech students",
    backstory="You are a research analyst who prepares short factual placement briefs in bullet form.",
    llm=llm,
    verbose=True,
    allow_delegation=False,
)

print("Researcher agent created")
# Out:
# Researcher agent created

# %%
writer = Agent(
    role="Placement Brief Writer",
    goal="Convert research notes into a clean 1-page placement brief in markdown",
    backstory="You write clear student-friendly placement briefs with headings and actionable takeaways.",
    llm=llm,
    verbose=True,
    allow_delegation=False,
)

print("Writer agent created")
# Out:
# Writer agent created

# %%
research_task = Task(
    description=(
        "Research TCS Digital placement preparation for B.Tech students. "
        "Include hiring process, technical stack, eligibility, recent hiring trends, "
        "and preparation tips. Give 3-5 bullets per section."
    ),
    agent=researcher,
    expected_output=(
        "Markdown bullet list with 5 sections: Hiring Process, Technical Stack, "
        "Eligibility, Recent Hiring Trends, Prep Tips."
    ),
)

print("Research task created")
# Out:
# Research task created

# %%
write_task = Task(
    description=(
        "Using the research notes, produce a 1-page placement brief for B.Tech students. "
        "Use markdown format. Include a 3-line opening hook, 5 clear sections, "
        "and a 3-line closing call-to-action."
    ),
    agent=writer,
    expected_output='1-page markdown brief titled "TCS Digital — Placement Prep Brief".',
)

print("Writer task created")
# Out:
# Writer task created

# %%
crew = Crew(
    agents=[researcher, writer],
    tasks=[research_task, write_task],
    process=Process.sequential,
    verbose=True,
)

print("Crew created successfully")
# Out:
# Crew created successfully

# %%
result = await crew.kickoff_async()

print("\n\n=== FINAL OUTPUT ===\n")
print(result)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: ddc72179-5132-4314-97fd-a156d69a9557                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │  ID: 7e61bc42-8d34-45ce-a3fe-b985ddeb22f5                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Task: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Here's a placement brief for TCS Digital preparation for B.Tech students:                                      │
# │                                                                                                                 │
# │  ### Hiring Process                                                                                             │
# │  *   **Online Assessment:** Typically includes sections on cognitive skills (numerical, verbal, logical         │
# │  ability), programming logic, and advanced coding challenges.                                                   │
# │  *   **Technical Interview:** Focuses on problem-solving, Data Structures & Algorithms (DSA), core computer     │
# │  science concepts (OS, DBMS, OOPS), and in-depth discussion of projects.                                        │
# │  *   **Managerial Interview:** Evaluates leadership potential, problem-solving approach to real-world           │
# │  scenarios, and alignment with company culture.                                                                 │
# │  *   **HR Interview:** Assesses communication skills, behavioral traits, career aspirations, and fit within     │
# │  the organization.                                                                                              │
# │                                                                                                                 │
# │  ### Technical Stack                                                                                            │
# │  *   **Core Programming Languages:** Strong proficiency in at least one language like Java, Python, C++, or C   │
# │  is essential.                                                                                                  │
# │  *   **Data Structures & Algorithms:** Deep understanding and application of common DSA concepts for optimal    │
# │  problem-solving.                                                                                               │
# │  *   **Database Knowledge:** Fundamentals of SQL, NoSQL databases, and database management systems.             │
# │  *   **Web Technologies (Optional but beneficial):** Basic understanding of frontend (HTML, CSS, JavaScript)    │
# │  and backend frameworks (e.g., Spring Boot, Django, Node.js).                                                   │
# │  *   **Emerging Technologies:** Awareness of concepts related to AI/ML, Cloud Computing (AWS, Azure, GCP),      │
# │  IoT, or Blockchain can be a significant advantage.                                                             │
# │                                                                                                                 │
# │  ### Eligibility                                                                                                │
# │  *   **Academic Percentage:** Generally requires a consistent academic record with a minimum aggregate of 60%   │
# │  or 6.0 CGPA throughout 10th, 12th, and B.Tech.                                                                 │
# │  *   **Degree:** Open to B.Tech/BE students from all engineering branches.                                      │
# │  *   **Backlogs:** Usually no active backlogs are allowed at the time of application or joining.                │
# │  *   **Age Limit:** Typically between 18 to 28 years at the time of application.                                │
# │                                                                                                                 │
# │  ### Recent Hiring Trends                                                                                       │
# │  *   **Advanced Technical Skills:** Higher emphasis on strong competitive programming skills and the ability    │
# │  to solve complex, real-world problems.                                                                         │
# │  *   **Domain Specialization:** Increased demand for candidates demonstrating interest or projects in specific  │
# │  digital domains like AI/ML, Cybersecurity, Data Science, or Cloud Engineering.                                 │
# │  *   **Practical Application:** Evaluation often includes live coding challenges and detailed discussions on    │
# │  project implementation and architectural choices.                                                              │
# │  *   **Adaptability & Learning Agility:** Companies seek candidates who are quick learners and adaptable to     │
# │  new technologies and evolving project requirements.                                                            │
# │  *   **Higher Compensation:** TCS Digital roles generally offer a higher compensation package compared to the   │
# │  TCS Ninja profile, reflecting the advanced skill set required.                                                 │
# │                                                                                                                 │
# │  ### Prep Tips                                                                                                  │
# │  *   **Master DSA:** Dedicate significant time to Data Structures and Algorithms; practice regularly on         │
# │  platforms like LeetCode, HackerRank, or GeeksforGeeks.                                                         │
# │  *   **Choose a Core Language:** Become highly proficient in one primary programming language (Java, Python,    │
# │  C++) and understand its advanced features.                                                                     │
# │  *   **Build Strong Projects:** Develop 2-3 impactful projects that showcase your technical skills and          │
# │  problem-solving abilities; be ready to explain them thoroughly.                                                │
# │  *   **Practice Mock Interviews:** Conduct mock technical and behavioral interviews to refine your              │
# │  communication skills and problem-solving approach under pressure.                                              │
# │  *   **Stay Updated:** Keep abreast of the latest technologies, industry trends, and fundamental concepts of    │
# │  emerging fields relevant to TCS's digital offerings.                                                           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │  ID: bb196338-d8f2-47fe-89d4-8eb6ddbe920b                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Task: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ERROR:root:Google Gemini API error: 503 - This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.
# ERROR:crewai.flow.flow:Error executing listener call_llm_and_parse: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# An unknown error occurred. Please check the details below.
# Error details: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# An unknown error occurred. Please check the details below.
# Error details: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# ╭───────────────────────────────────────────────── ❌ LLM Error ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  LLM Call Failed                                                                                                │
# │  Error: Google Gemini API error: 503 - This model is currently experiencing high demand. Spikes in demand are   │
# │  usually temporary. Please try again later.                                                                     │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Task: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  # TCS Digital — Placement Prep Brief                                                                           │
# │                                                                                                                 │
# │  Dreaming of a high-impact career in digital transformation? TCS Digital offers a premium pathway for B.Tech    │
# │  graduates to dive into advanced technologies and cutting-edge projects. This brief is your essential guide to  │
# │  navigating the selection process and landing a coveted role.                                                   │
# │                                                                                                                 │
# │  ### 1. The Hiring Journey                                                                                      │
# │                                                                                                                 │
# │  The TCS Digital selection process is rigorous and designed to identify top talent. Be ready for:               │
# │                                                                                                                 │
# │  *   **Online Assessment:** Tests cognitive abilities (verbal, logical, numerical), programming logic, and      │
# │  advanced coding challenges.                                                                                    │
# │  *   **Technical Interview:** Deep dive into problem-solving, DSA, core CS fundamentals (OS, DBMS, OOPS), and   │
# │  your project work.                                                                                             │
# │  *   **Managerial Interview:** Evaluates leadership potential, real-world problem-solving, and cultural fit     │
# │  within TCS.                                                                                                    │
# │  *   **HR Interview:** Assesses communication skills, behavioral traits, career aspirations, and overall        │
# │  organizational fit.                                                                                            │
# │                                                                                                                 │
# │  ### 2. Technical Stack Essentials                                                                              │
# │                                                                                                                 │
# │  Mastering these areas is non-negotiable for TCS Digital:                                                       │
# │                                                                                                                 │
# │  *   **Core Programming:** Strong command over one language: Java, Python, C++, or C. Understand advanced       │
# │  features.                                                                                                      │
# │  *   **Data Structures & Algorithms (DSA):** Comprehensive knowledge and efficient application of DSA for       │
# │  optimal solutions.                                                                                             │
# │  *   **Database Fundamentals:** Grasp SQL basics, NoSQL concepts, and database management principles.           │
# │  *   **Web Technologies (Bonus):** Basic understanding of frontend (HTML, CSS, JS) and backend frameworks       │
# │  (e.g., Spring Boot, Django) is a plus.                                                                         │
# │  *   **Emerging Tech Awareness:** Familiarity with AI/ML, Cloud (AWS, Azure, GCP), IoT, or Blockchain gives     │
# │  you an edge.                                                                                                   │
# │                                                                                                                 │
# │  ### 3. Eligibility Criteria                                                                                    │
# │                                                                                                                 │
# │  Ensure you meet these prerequisites to apply:                                                                  │
# │                                                                                                                 │
# │  *   **Academic Record:** Consistent academic performance with a minimum aggregate of 60% or 6.0 CGPA           │
# │  throughout 10th, 12th, and B.Tech.                                                                             │
# │  *   **Degree:** Open to B.Tech/BE students from all engineering branches.                                      │
# │  *   **Backlogs:** Generally, no active backlogs are permitted at the time of application or joining.           │
# │  *   **Age Limit:** Typically between 18 to 28 years at the time of application.                                │
# │                                                                                                                 │
# │  ### 4. What's Hot: Recent Trends                                                                               │
# │                                                                                                                 │
# │  TCS Digital looks for candidates who are not just skilled, but forward-thinking:                               │
# │                                                                                                                 │
# │  *   **Advanced Problem-Solving:** High emphasis on competitive programming skills and the ability to tackle    │
# │  complex, real-world scenarios.                                                                                 │
# │  *   **Domain Specialization:** Demonstrated interest and projects in digital domains like AI/ML,               │
# │  Cybersecurity, Data Science, or Cloud Engineering are highly valued.                                           │
# │  *   **Practical Application:** Expect live coding challenges and detailed discussions on your project's        │
# │  implementation and architectural choices.                                                                      │
# │  *   **Adaptability & Learning Agility:** A quick learner who can adapt to new technologies and project         │
# │  requirements is key.                                                                                           │
# │  *   **Higher Compensation:** TCS Digital roles offer a significantly more attractive compensation package      │
# │  compared to the TCS Ninja profile.                                                                             │
# │                                                                                                                 │
# │  ### 5. Your Prep Roadmap                                                                                       │
# │                                                                                                                 │
# │  Follow these tips to maximize your chances:                                                                    │
# │                                                                                                                 │
# │  *   **Master DSA:** Devote substantial time to Data Structures & Algorithms. Practice consistently on          │
# │  platforms like LeetCode, HackerRank, and GeeksforGeeks.                                                        │
# │  *   **Proficiency in One Language:** Become expert in your chosen core programming language (Java, Python,     │
# │  C++).                                                                                                          │
# │  *   **Build Strong Projects:** Develop 2-3 impactful projects. Be ready to explain your logic, tech stack,     │
# │  and contributions in detail.                                                                                   │
# │  *   **Practice Mock Interviews:** Conduct both technical and behavioral mock interviews to refine your         │
# │  communication and problem-solving under pressure.                                                              │
# │  *   **Stay Updated:** Keep up with the latest technologies, industry trends, and fundamental concepts in       │
# │  emerging digital fields.                                                                                       │
# │                                                                                                                 │
# │  Your journey to a dynamic career at TCS Digital begins now. Prepare diligently, showcase your potential, and   │
# │  seize this incredible opportunity to innovate. Good luck!                                                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === FINAL OUTPUT ===
#
# # TCS Digital — Placement Prep Brief
#
# Dreaming of a high-impact career in digital transformation? TCS Digital offers a premium pathway for B.Tech graduates to dive into advanced technologies and cutting-edge projects. This brief is your essential guide to navigating the selection process and landing a coveted role.
#
# ### 1. The Hiring Journey
#
# The TCS Digital selection process is rigorous and designed to identify top talent. Be ready for:
#
# *   **Online Assessment:** Tests cognitive abilities (verbal, logical, numerical), programming logic, and advanced coding challenges.
# *   **Technical Interview:** Deep dive into problem-solving, DSA, core CS fundamentals (OS, DBMS, OOPS), and your project work.
# *   **Managerial Interview:** Evaluates leadership potential, real-world problem-solving, and cultural fit within TCS.
# *   **HR Interview:** Assesses communication skills, behavioral traits, career aspirations, and overall organizational fit.
#
# ### 2. Technical Stack Essentials
#
# Mastering these areas is non-negotiable for TCS Digital:
#
# *   **Core Programming:** Strong command over one language: Java, Python, C++, or C. Understand advanced features.
# *   **Data Structures & Algorithms (DSA):** Comprehensive knowledge and efficient application of DSA for optimal solutions.
# *   **Database Fundamentals:** Grasp SQL basics, NoSQL concepts, and database management principles.
# *   **Web Technologies (Bonus):** Basic understanding of frontend (HTML, CSS, JS) and backend frameworks (e.g., Spring Boot, Django) is a plus.
# *   **Emerging Tech Awareness:** Familiarity with AI/ML, Cloud (AWS, Azure, GCP), IoT, or Blockchain gives you an edge.
#
# ### 3. Eligibility Criteria
#
# Ensure you meet these prerequisites to apply:
#
# *   **Academic Record:** Consistent academic performance with a minimum aggregate of 60% or 6.0 CGPA throughout 10th, 12th, and B.Tech.
# *   **Degree:** Open to B.Tech/BE students from all engineering branches.
# *   **Backlogs:** Generally, no active backlogs are permitted at the time of application or joining.
# *   **Age Limit:** Typically between 18 to 28 years at the time of application.
#
# ### 4. What's Hot: Recent Trends
#
# TCS Digital looks for candidates who are not just skilled, but forward-thinking:
#
# *   **Advanced Problem-Solving:** High emphasis on competitive programming skills and the ability to tackle complex, real-world scenarios.
# *   **Domain Specialization:** Demonstrated interest and projects in digital domains like AI/ML, Cybersecurity, Data Science, or Cloud Engineering are highly valued.
# *   **Practical Application:** Expect live coding challenges and detailed discussions on your project's implementation and architectural choices.
# *   **Adaptability & Learning Agility:** A quick learner who can adapt to new technologies and project requirements is key.
# *   **Higher Compensation:** TCS Digital roles offer a significantly more attractive compensation package compared to the TCS Ninja profile.
#
# ### 5. Your Prep Roadmap
#
# Follow these tips to maximize your chances:
#
# *   **Master DSA:** Devote substantial time to Data Structures & Algorithms. Practice consistently on platforms like LeetCode, HackerRank, and GeeksforGeeks.
# *   **Proficiency in One Language:** Become expert in your chosen core programming language (Java, Python, C++).
# *   **Build Strong Projects:** Develop 2-3 impactful projects. Be ready to explain your logic, tech stack, and contributions in detail.
# *   **Practice Mock Interviews:** Conduct both technical and behavioral mock interviews to refine your communication and problem-solving under pressure.
# *   **Stay Updated:** Keep up with the latest technologies, industry trends, and fundamental concepts in emerging digital fields.
#
# Your journey to a dynamic career at TCS Digital begins now. Prepare diligently, showcase your potential, and seize this incredible opportunity to innovate. Good luck!

# %%
import pathlib

pathlib.Path("day10_lab10a_transcript.txt").write_text(str(result))

print("Saved: day10_lab10a_transcript.txt")
print("Characters:", len(str(result)))
# Out:
# Saved: day10_lab10a_transcript.txt
# Characters: 3876

# %%
try:
    for i, output in enumerate(result.tasks_output):
        print(f"\n=== Task {i+1} Output ===")
        print(str(output)[:800])
except Exception:
    print("Task outputs not available in this CrewAI version.")
    print("Final result saved successfully.")
# Out:
# === Task 1 Output ===
# Here's a placement brief for TCS Digital preparation for B.Tech students:
#
# ### Hiring Process
# *   **Online Assessment:** Typically includes sections on cognitive skills (numerical, verbal, logical ability), programming logic, and advanced coding challenges.
# *   **Technical Interview:** Focuses on problem-solving, Data Structures & Algorithms (DSA), core computer science concepts (OS, DBMS, OOPS), and in-depth discussion of projects.
# *   **Managerial Interview:** Evaluates leadership potential, problem-solving approach to real-world scenarios, and alignment with company culture.
# *   **HR Interview:** Assesses communication skills, behavioral traits, career aspirations, and fit within the organization.
#
# ### Technical Stack
# *   **Core Programming Languages:** Strong proficiency in at least on
#
# === Task 2 Output ===
# # TCS Digital — Placement Prep Brief
#
# Dreaming of a high-impact career in digital transformation? TCS Digital offers a premium pathway for B.Tech graduates to dive into advanced technologies and cutting-edge projects. This brief is your essential guide to navigating the selection process and landing a coveted role.
#
# ### 1. The Hiring Journey
#
# The TCS Digital selection process is rigorous and designed to identify top talent. Be ready for:
#
# *   **Online Assessment:** Tests cognitive abilities (verbal, logical, numerical), programming logic, and advanced coding challenges.
# *   **Technical Interview:** Deep dive into problem-solving, DSA, core CS fundamentals (OS, DBMS, OOPS), and your project work.
# *   **Managerial Interview:** Evaluates leadership potential, real-world problem-solving, and c

# %%
markdown_content = str(result)

with open("tcs_digital_brief.md", "w", encoding="utf-8") as f:
    f.write(markdown_content)

print("Markdown file created successfully: tcs_digital_brief.md")
# Out:
# Markdown file created successfully: tcs_digital_brief.md

# %%
from google.colab import files

files.download("tcs_digital_brief.md")

# %%
with open("tcs_digital_brief.md", "r", encoding="utf-8") as f:
    print(f.read()[:2000])
# Out:
# # TCS Digital — Placement Prep Brief
#
# Dreaming of a high-impact career in digital transformation? TCS Digital offers a premium pathway for B.Tech graduates to dive into advanced technologies and cutting-edge projects. This brief is your essential guide to navigating the selection process and landing a coveted role.
#
# ### 1. The Hiring Journey
#
# The TCS Digital selection process is rigorous and designed to identify top talent. Be ready for:
#
# *   **Online Assessment:** Tests cognitive abilities (verbal, logical, numerical), programming logic, and advanced coding challenges.
# *   **Technical Interview:** Deep dive into problem-solving, DSA, core CS fundamentals (OS, DBMS, OOPS), and your project work.
# *   **Managerial Interview:** Evaluates leadership potential, real-world problem-solving, and cultural fit within TCS.
# *   **HR Interview:** Assesses communication skills, behavioral traits, career aspirations, and overall organizational fit.
#
# ### 2. Technical Stack Essentials
#
# Mastering these areas is non-negotiable for TCS Digital:
#
# *   **Core Programming:** Strong command over one language: Java, Python, C++, or C. Understand advanced features.
# *   **Data Structures & Algorithms (DSA):** Comprehensive knowledge and efficient application of DSA for optimal solutions.
# *   **Database Fundamentals:** Grasp SQL basics, NoSQL concepts, and database management principles.
# *   **Web Technologies (Bonus):** Basic understanding of frontend (HTML, CSS, JS) and backend frameworks (e.g., Spring Boot, Django) is a plus.
# *   **Emerging Tech Awareness:** Familiarity with AI/ML, Cloud (AWS, Azure, GCP), IoT, or Blockchain gives you an edge.
#
# ### 3. Eligibility Criteria
#
# Ensure you meet these prerequisites to apply:
#
# *   **Academic Record:** Consistent academic performance with a minimum aggregate of 60% or 6.0 CGPA throughout 10th, 12th, and B.Tech.
# *   **Degree:** Open to B.Tech/BE students from all engineering branches.
# *   **Backlogs:** Generally, no active backlogs are permitted at th
